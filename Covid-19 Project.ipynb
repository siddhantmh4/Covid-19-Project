# %% [markdown]
# # 1. From epidemic to pandemic

# %% [markdown]
# <img src="CDC.png" style="width:250px;height:250"/>

# %% [markdown]
# # In December 2019, COVID-19 coronavirus was first identified in the Wuhan region of China. By March 11, 2020, the World Health Organization (WHO) categorized the COVID-19 outbreak as a pandemic. A lot has happened in the months in between with major outbreaks in some Countries.
#
# We know that COVID-19 spreads through respiratory droplets, such as through coughing, sneezing, or speaking. But, how quickly did the virus spread across the globe? And, can we see any effect from country-wide policies, like shutdowns and quarantines?
#
# Fortunately, organizations around the world have been collecting data so that governments can monitor and learn from this pandemic. Notably, the Johns Hopkins University Center for Systems Science and Engineering created a publicly available data repository to consolidate this data from sources like the WHO, the Centers for Disease Control and Prevention (CDC), and the Ministry of Health from multiple countries.
#
# In this notebook, you will visualize COVID-19 data from the first several months of the outbreak to see at what point this virus became a global pandemic.
#
# The data used in this project was pulled on March 30, 2020, and should not be considered to be the most up to date data available.

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# # 2. Which countries outside of China have been hit hardest?

# %% [markdown]
# # Top 10 Infected Countries

# %%
import folium
map=folium.Map()
#Top 10 Infected Countries
countries = [
    {'loc': [37.090240,  -95.712891], 'label': 'USA'},
    {'loc': [-14.235004, -51.925282], 'label': 'Brazil'},
    {'loc': [22.5431,  114.0579], 'label': 'Russia'},
    {'loc': [37.4970,  127.0266], 'label': 'Spain'},
    {'loc': [55.378052, -3.435973], 'label': 'UK'},
    {'loc': [41.8719 ,  12.5674], 'label': 'Itly'},
    {'loc': [46.2276, 2.2137], 'label': 'France'},
    {'loc': [51.1657, 10.4515], 'label': 'Germany'},
    {'loc': [20.5937, 78.9629], 'label': 'India'},
    {'loc': [38.9637,35.2433], 'label': 'Turkey'}]

for country in countries:
    marker=folium.Marker(location=country['loc'],popup=country['label'])
    marker.add_to(map)
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
Countries=["USA","Brazil","Russia","Spain","Uk","Itly","France","Germany","India","Turkey"]
Cases=[1775488,438812,387623,285644,269127,232248,186238,182711,172359,160979]
plt.title("Top 10 Countries Infected By Corona Virus")
plt.xlabel("Countries")
plt.ylabel("Infected [In Lakhs]")
plt.fill_between(Countries,Cases,0,color="orange")

# %%
india=pd.read_csv(r"C:\Users\HP\Downloads\india.csv")

# %%
sns.relplot(x="Confirmed",y="State/UnionTerritory",hue='Cured',data=india)

# %% [markdown]
# # 3. Let's annotate Our World!

# %% [markdown]
# <img src="dr1.png" style="width:800px;height:200px"/>

# %% [markdown]
# # Total Cases In India

# %%
data=pd.read_csv(r"C:\Users\HP\Downloads\sets.csv")

# %%
data
# Out:
#    Sno AgeGroup  TotalCases Percentage
# 0    1      0-9          22      3.18%
# 1    2    10-19          27      3.90%
# 2    3    20-29         172     24.86%
# 3    4    30-39         146     21.10%
# 4    5    40-49         112     16.18%
# 5    6    50-59          77     11.13%
# 6    7    60-69          89     12.86%
# 7    8    70-79          28      4.05%
# 8    9     >=80          10      1.45%
# 9   10  Missing           9      1.30%

# %%
plt.plot("AgeGroup","TotalCases",data=data)
plt.show()

# %%
Months=["February","March","April","May"]
total_cases=[10,1397,32213,133587]
plt.title("Total Cases")
plt.xlabel=("Months")
plt.ylabel=("Total Cases")
plt.fill_between(Months,total_cases,0,color="DarkOrange")

# %% [markdown]
# # Total Recoveries in India

# %%
Months=["April","May"]
Recoveries=[8373,62733]
plt.fill_between(Months,Recoveries,0,color="green")
plt.show()

# %% [markdown]
# # Total Deaths In India

# %%
Months=["February","March","April","May"]
total_deaths=[0,28,1111,4012]
plt.title("Total Deaths")
plt.fill_between(Months,total_deaths,0,color="Crimson")
plt.show()

# %% [markdown]
# # 4. China compared to the rest of the world

# %%
tt=pd.read_csv(r"C:\Users\HP\Downloads\total_cases.csv")
td=pd.read_csv(r"C:\Users\HP\Downloads\total_deaths.csv")

# %%
plt.hist("China",bins="auto",density=False,alpha=0.9,rwidth=0.85,facecolor='orange',data=tt)
plt.title("Total Cases in China")
#plt.xlabel("Total Cases")
#plt.ylabel("DAYS")
# Out:
# Text(0.5, 1.0, 'Total Cases in China')

# %%
plt.hist("China",bins="auto",alpha=0.9,facecolor='red',rwidth=0.85,data=td)
plt.title("Total Deaths in China")
# Out:
# Text(0.5, 1.0, 'Total Deaths in China')

# %% [markdown]
# # 4. Let's annotate!

# %% [markdown]
# <img src="1.jpg" style=width:300px;height:200px>

# %% [markdown]
# # Impact of COVID-19 on National Stock Exchange of India NIFTY 50 (1 Jan 2020 to 19 May 2020).

# %%
Date=["30_January","2_March","12 March","25_March","12_May"]
value=[12211,11500,10089,8200,9600]
#ylabel("Share Price")
plt.fill_between(Date,value,0,color="MediumVioletRed")
plt.show()

# %% [markdown]
# The GDP of a country tends to increase when the total value of goods and services that domestic producers sell to foreign countries exceeds the total value of foreign goods and services that domestic consumers buy. When this situation occurs, a country is said to have a trade surplus. If the opposite situation occurs–if the amount that domestic consumers spend on foreign products is greater than the total sum of what domestic producers are able to sell to foreign consumers–it is called a trade deficit. In this situation, the GDP of a country tends to decrease.#

# %% [markdown]
# # India's GDP growth rate since FY16

# %%
FY=["FY16","FY17","FY18","FY19","FY20","FY21"]
GDP=[8.0,8.3,6.6,6.1,4.2,-5.0]
#plt.xlabel("Fiscal Year")
#plt.ylabel("GDP")
plt.fill_between(FY,GDP,0,color="MediumSpringGreen")
plt.show()
